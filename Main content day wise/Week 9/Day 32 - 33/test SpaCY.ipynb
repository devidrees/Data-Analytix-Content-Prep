# %%
import spacy
from spacy.pipeline.textcat import Config, TextCategorizer
from spacy.training.example import Example
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import spacy
#       2 from spacy.pipeline.textcat import Config, TextCategorizer
#       3 from spacy.training.example import Example
#
# ModuleNotFoundError: No module named 'spacy'

# %%
pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in c:\users\devid\desktop\xdata-analytix-content-prep\testenv\lib\site-packages (24.3.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install spacy
# Out:
# Collecting spacy
#   Using cached spacy-3.8.2.tar.gz (1.3 MB)
#   Installing build dependencies: started
#   Installing build dependencies: still running...
#   Installing build dependencies: still running...
#   Installing build dependencies: still running...
#   Installing build dependencies: still running...
#   Installing build dependencies: still running...
#   Installing build dependencies: still running...
#   Installing build dependencies: still running...
#   Installing build dependencies: still running...
#   Installing build dependencies: still running...
#   Installing build dependencies: still running...
#   Installing build dependencies: still running...
#   Installing build dependencies: still running...
#   Installing build dependencies: still running...
#   Installing build dependencies: still running...
#   Installing build dependencies: still running...
#   Installing build dependencies: still running...
#   Installing build dependencies: still running...
#   Installing build dependencies: still running...
#   Installing build dependencies: still running...
#   Installing build dependencies: finished with status 'error'
#   error: subprocess-exited-with-error
#
#   × pip subprocess to install build dependencies did not run successfully.
#   │ exit code: 1
#   ╰─> [955 lines of output]
#       Ignoring numpy: markers 'python_version < "3.9"' don't match your environment
#       Collecting setuptools
#         Using cached setuptools-75.6.0-py3-none-any.whl.metadata (6.7 kB)
#       Collecting cython<3.0,>=0.25
#         Using cached Cython-0.29.37-py2.py3-none-any.whl.metadata (3.1 kB)
#       Collecting cymem<2.1.0,>=2.0.2
#         Using cached cymem-2.0.10-cp313-cp313-win_amd64.whl.metadata (8.6 kB)
#       Collecting preshed<3.1.0,>=3.0.2
#         Using cached preshed-3.0.9-cp313-cp313-win_amd64.whl
#       Collecting murmurhash<1.1.0,>=0.28.0
#         Using cached murmurhash-1.0.11-cp313-cp313-win_amd64.whl.metadata (2.0 kB)
#       Collecting thinc<8.4.0,>=8.3.0
#         Using cached thinc-8.3.2.tar.gz (193 kB)
#         Installing build dependencies: started
#         Installing build dependencies: still running...
#         Installing build dependencies: still running...
#         Installing build dependencies: still running...
#         Installing build dependencies: still running...
#         Installing build dependencies: still running...
#         Installing build dependencies: still running...
#         Installing build dependencies: still running...
#         Installing build dependencies: still running...
#         Installing build dependencies: still running...
#         Installing build dependencies: still running...
#         Installing build dependencies: still running...
#         Installing build dependencies: still running...
#         Installing build dependencies: still running...
#         Installing build dependencies: still running...
#         Installing build dependencies: still running...
#         Installing build dependencies: still running...
#         Installing build dependencies: still running...
#         Installing build dependencies: still running...
#         Installing build dependencies: still running...
#         Installing build dependencies: finished with status 'error'
#         error: subprocess-exited-with-error
#
#         Ã— pip subprocess to install build dependencies did not run successfully.
#         â”‚ exit code: 1
#         â•°â”€> [906 lines of output]
#             Ignoring numpy: markers 'python_version < "3.9"' don't match your environment
#             Collecting setuptools
#               Using cached setuptools-75.6.0-py3-none-any.whl.metadata (6.7 kB)
#             Collecting cython<3.0,>=0.25
#               Using cached Cython-0.29.37-py2.py3-none-any.whl.metadata (3.1 kB)
#             Collecting murmurhash<1.1.0,>=1.0.2
#               Using cached murmurhash-1.0.11-cp313-cp313-win_amd64.whl.metadata (2.0 kB)
#             Collecting cymem<2.1.0,>=2.0.2
#               Using cached cymem-2.0.10-cp313-cp313-win_amd64.whl.metadata (8.6 kB)
#             Collecting preshed<3.1.0,>=3.0.2
#               Using cached preshed-3.0.9-cp313-cp313-win_amd64.whl
#             Collecting blis<1.1.0,>=1.0.0
#               Using cached blis-1.0.1.tar.gz (3.6 MB)
#               Installing build dependencies: started
#               Installing build dependencies: finished with status 'done'
#               Getting requirements to build wheel: started
#               Getting requirements to build wheel: finished with status 'done'
#               Preparing metadata (pyproject.toml): started
#               Preparing metadata (pyproject.toml): finished with status 'done'
#             Collecting numpy<2.1.0,>=2.0.0
#               Using cached numpy-2.0.2-cp313-cp313-win_amd64.whl
#             Using cached setuptools-75.6.0-py3-none-any.whl (1.2 MB)
#             Using cached Cython-0.29.37-py2.py3-none-any.whl (989 kB)
#             Using cached murmurhash-1.0.11-cp313-cp313-win_amd64.whl (24 kB)
#             Using cached cymem-2.0.10-cp313-cp313-win_amd64.whl (39 kB)
#             Building wheels for collected packages: blis
#               Building wheel for blis (pyproject.toml): started
#               Building wheel for blis (pyproject.toml): still running...
#               Building wheel for blis (pyproject.toml): still running...
#               Building wheel for blis (pyproject.toml): still running...
#               Building wheel for blis (pyproject.toml): still running...
#               Building wheel for blis (pyproject.toml): still running...
#               Building wheel for blis (pyproject.toml): still running...
#               Building wheel for blis (pyproject.toml): still running...
#               Building wheel for blis (pyproject.toml): still running...
#               Building wheel for blis (pyproject.toml): still running...
#               Building wheel for blis (pyproject.toml): still running...
#               Building wheel for blis (pyproject.toml): still running...
#               Building wheel for blis (pyproject.toml): still running...
#               Building wheel for blis (pyproject.toml): still running...
#               Building wheel for blis (pyproject.toml): still running...
#               Building wheel for blis (pyproject.toml): still running...
#               Building wheel for blis (pyproject.toml): still running...
#               Building wheel for blis (pyproject.toml): still running...
#               Building wheel for blis (pyproject.toml): still running...
#               Building wheel for blis (pyproject.toml): still running...
#               Building wheel for blis (pyproject.toml): finished with status 'error'
#               error: subprocess-exited-with-error
#
#               Ãƒâ€” Building wheel for blis (pyproject.toml) did not run successfully.
#               Ã¢â€\x9dâ€š exit code: 1
#               Ã¢â€¢Â°Ã¢â€\x9dâ‚¬> [848 lines of output]
#                   BLIS_COMPILER? None
#                   running bdist_wheel
#                   running build
#                   running build_py
#                   creating build\lib.win-amd64-cpython-313\blis
#                   copying blis\about.py -> build\lib.win-amd64-cpython-313\blis
#                   copying blis\benchmark.py -> build\lib.win-amd64-cpython-313\blis
#                   copying blis\__init__.py -> build\lib.win-amd64-cpython-313\blis
#                   creating build\lib.win-amd64-cpython-313\blis\tests
#                   copying blis\tests\common.py -> build\lib.win-amd64-cpython-313\blis\tests
#                   copying blis\tests\conftest.py -> build\lib.win-amd64-cpython-313\blis\tests
#                   copying blis\tests\test_dotv.py -> build\lib.win-amd64-cpython-313\blis\tests
#                   copying blis\tests\test_gemm.py -> build\lib.win-amd64-cpython-313\blis\tests
#                   copying blis\tests\__init__.py -> build\lib.win-amd64-cpython-313\blis\tests
#                   copying blis\cy.pyx -> build\lib.win-amd64-cpython-313\blis
#                   copying blis\py.pyx -> build\lib.win-amd64-cpython-313\blis
#                   copying blis\cy.pxd -> build\lib.win-amd64-cpython-313\blis
#                   copying blis\__init__.pxd -> build\lib.win-amd64-cpython-313\blis
#                   running build_ext
#                   Build options win32 msvc
#                   BUILD ARCH: x86_64
#                   {'!EXITCODE': '00000000', 'ACLOCAL_PATH': 'C:\\Program Files\\Git\\mingw64\\share\\aclocal;C:\\Program Files\\Git\\usr\\share\\aclocal', 'AGENT_BUILDDIRECTORY': 'D:\\a\\1', 'AGENT_DISABLELOGPLUGIN_TESTFILEPUBLISHERPLUGIN': 'true', 'AGENT_DISABLELOGPLUGIN_TESTRESULTLOGPLUGIN': 'false', 'AGENT_HOMEDIRECTORY': 'C:\\agents\\2.202.0', 'AGENT_ID': '92', 'AGENT_JOBNAME': 'JSONL Python38Windows', 'AGENT_JOBSTATUS': 'Succeeded', 'AGENT_LOGTOBLOBSTORAGESERVICE': 'true', 'AGENT_MACHINENAME': 'WIN-CU8INV6766V', 'AGENT_NAME': 'Hosted Agent', 'AGENT_OS': 'Windows_NT', 'AGENT_OSARCHITECTURE': 'X64', 'AGENT_READONLYVARIABLES': 'true', 'AGENT_RETAINDEFAULTENCODING': 'false', 'AGENT_ROOTDIRECTORY': 'D:\\a', 'AGENT_SERVEROMDIRECTORY': 'C:\\agents\\2.202.0\\externals\\vstsom', 'AGENT_TASKRESTRICTIONSENFORCEMENTMODE': 'Enabled', 'AGENT_TEMPDIRECTORY': 'D:\\a\\_temp', 'AGENT_TOOLSDIRECTORY': 'C:\\hostedtoolcache\\windows', 'AGENT_USEWORKSPACEID': 'true', 'AGENT_VERSION': '2.202.0', 'AGENT_WORKFOLDER': 'D:\\a', 'ALLUSERSPROFILE': 'C:\\ProgramData', 'ANDROID_HOME': 'C:\\Android\\android-sdk', 'ANDROID_NDK_HOME': 'C:\\Android\\android-sdk\\ndk-bundle', 'ANDROID_NDK_LATEST_HOME': 'C:\\Android\\android-sdk\\ndk\\23.1.7779620', 'ANDROID_NDK_PATH': 'C:\\Android\\android-sdk\\ndk-bundle', 'ANDROID_NDK_ROOT': 'C:\\Android\\android-sdk\\ndk-bundle', 'ANDROID_SDK_ROOT': 'C:\\Android\\android-sdk', 'ANT_HOME': 'C:\\ProgramData\\chocolatey\\lib\\ant\\tools\\apache-ant-1.10.12', 'APPDATA': 'C:\\Users\\VssAdministrator\\AppData\\Roaming', 'AR': 'llvm-ar', 'AS': 'llvm-as', 'AZURE_EXTENSION_DIR': 'C:\\Program Files\\Common Files\\AzureCliExtensionDirectory', 'AZURE_HTTP_USER_AGENT': 'VSTS_116cc368-5c0c-4eb4-bb44-7f3fa5bdce14_build_6_0', 'BUILD_ARTIFACTSTAGINGDIRECTORY': 'D:\\a\\1\\a', 'BUILD_BINARIESDIRECTORY': 'D:\\a\\1\\b', 'BUILD_BUILDID': '17021', 'BUILD_BUILDNUMBER': '20220408.7', 'BUILD_BUILDURI': 'vstfs:///Build/Build/17021', 'BUILD_CONTAINERID': '11809685', 'BUILD_DEFINITIONNAME': 'explosion.cython-blis', 'BUILD_DEFINITIONVERSION': '1', 'BUILD_QUEUEDBY': 'GitHub', 'BUILD_QUEUEDBYID': '38e7e9f7-fc06-4f5a-b6dd-1782f4ef7c25', 'BUILD_REASON': 'PullRequest', 'BUILD_REPOSITORY_GIT_SUBMODULECHECKOUT': 'False', 'BUILD_REPOSITORY_ID': 'explosion/cython-blis', 'BUILD_REPOSITORY_LOCALPATH': 'D:\\a\\1\\s', 'BUILD_REPOSITORY_NAME': 'explosion/cython-blis', 'BUILD_REPOSITORY_PROVIDER': 'GitHub', 'BUILD_REPOSITORY_URI': 'https://github.com/explosion/cython-blis', 'BUILD_REQUESTEDFOR': 'GitHub', 'BUILD_REQUESTEDFOREMAIL': '', 'BUILD_REQUESTEDFORID': '38e7e9f7-fc06-4f5a-b6dd-1782f4ef7c25', 'BUILD_SOURCEBRANCH': 'refs/pull/69/merge', 'BUILD_SOURCEBRANCHNAME': 'merge', 'BUILD_SOURCESDIRECTORY': 'D:\\a\\1\\s', 'BUILD_SOURCEVERSION': '273ec162fa5f042b5d946638cedd954583ff8111', 'BUILD_SOURCEVERSIONAUTHOR': 'DaniÃƒÆ’Ã‚Â«l de Kok', 'BUILD_SOURCEVERSIONMESSAGE': 'Merge 1de7a1931422b892af086ce69604e7e3459e9f8e into 6daabf0c925bfe67f7d87874ce014eb3212711e7', 'BUILD_STAGINGDIRECTORY': 'D:\\a\\1\\a', 'CABAL_DIR': 'C:\\cabal', 'CC': 'clang', 'COBERTURA_HOME': 'C:\\cobertura-2.1.1', 'COMMONPROGRAMFILES': 'C:\\Program Files\\Common Files', 'COMMON_TESTRESULTSDIRECTORY': 'D:\\a\\1\\TestResults', 'COMPUTERNAME': 'WIN-CU8INV6766V', 'COMSPEC': 'C:\\Windows\\system32\\cmd.exe', 'CONDA': 'C:\\Miniconda', 'CONFIG_SITE': 'C:/Program Files/Git/etc/config.site', 'CHOCOLATEYINSTALL': 'C:\\ProgramData\\chocolatey', 'CHROMEWEBDRIVER': 'C:\\SeleniumWebDrivers\\ChromeDriver', 'COMMONPROGRAMFILES(X86)': 'C:\\Program Files (x86)\\Common Files', 'COMMONPROGRAMW6432': 'C:\\Program Files\\Common Files', 'DISPLAY': 'needs-to-be-defined', 'DOTNET_MULTILEVEL_LOOKUP': '0', 'DRIVERDATA': 'C:\\Windows\\System32\\Drivers\\DriverData', 'EXEPATH': 'C:\\Program Files\\Git\\bin', 'EDGEWEBDRIVER': 'C:\\SeleniumWebDrivers\\EdgeDriver', 'GCM_INTERACTIVE': 'Never', 'GHCUP_INSTALL_BASE_PREFIX': 'C:\\', 'GHCUP_MSYS2': 'C:\\msys64', 'GIT_TERMINAL_PROMPT': '0', 'GOROOT_1_15_X64': 'C:\\hostedtoolcache\\windows ...
#                   [COMMAND] C:\MinGW\bin\clang.exe -c C:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\config\bulldozer\bli_cntx_init_bulldozer.c -o C:\Users\devid\AppData\Local\Temp\tmpd3ag3zpf\bli_cntx_init_bulldozer.o -O2 -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.9.0" -DBLIS_IS_BUILDING_LIBRARY -Iinclude\windows-x86_64 -I.\frame\3\ -I.\frame\1m\ -I.\frame\1f\ -I.\frame\1\ -I.\frame\include -IC:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\include\windows-x86_64
#                   [COMMAND] C:\MinGW\bin\clang.exe -c C:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\config\excavator\bli_cntx_init_excavator.c -o C:\Users\devid\AppData\Local\Temp\tmpd3ag3zpf\bli_cntx_init_excavator.o -O2 -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.9.0" -DBLIS_IS_BUILDING_LIBRARY -Iinclude\windows-x86_64 -I.\frame\3\ -I.\frame\1m\ -I.\frame\1f\ -I.\frame\1\ -I.\frame\include -IC:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\include\windows-x86_64
#                   [COMMAND] C:\MinGW\bin\clang.exe -c C:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\config\generic\bli_cntx_init_generic.c -o C:\Users\devid\AppData\Local\Temp\tmpd3ag3zpf\bli_cntx_init_generic.o -O2 -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.9.0" -DBLIS_IS_BUILDING_LIBRARY -Iinclude\windows-x86_64 -I.\frame\3\ -I.\frame\1m\ -I.\frame\1f\ -I.\frame\1\ -I.\frame\include -IC:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\include\windows-x86_64
#                   [COMMAND] C:\MinGW\bin\clang.exe -c C:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\config\haswell\bli_cntx_init_haswell.c -o C:\Users\devid\AppData\Local\Temp\tmpd3ag3zpf\bli_cntx_init_haswell.o -O2 -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.9.0" -DBLIS_IS_BUILDING_LIBRARY -Iinclude\windows-x86_64 -I.\frame\3\ -I.\frame\1m\ -I.\frame\1f\ -I.\frame\1\ -I.\frame\include -IC:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\include\windows-x86_64
#                   [COMMAND] C:\MinGW\bin\clang.exe -c C:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\config\knl\bli_cntx_init_knl.c -o C:\Users\devid\AppData\Local\Temp\tmpd3ag3zpf\bli_cntx_init_knl.o -O2 -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.9.0" -DBLIS_IS_BUILDING_LIBRARY -Iinclude\windows-x86_64 -I.\frame\3\ -I.\frame\1m\ -I.\frame\1f\ -I.\frame\1\ -I.\frame\include -IC:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\include\windows-x86_64
#                   [COMMAND] C:\MinGW\bin\clang.exe -c C:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\config\penryn\bli_cntx_init_penryn.c -o C:\Users\devid\AppData\Local\Temp\tmpd3ag3zpf\bli_cntx_init_penryn.o -O2 -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.9.0" -DBLIS_IS_BUILDING_LIBRARY -Iinclude\windows-x86_64 -I.\frame\3\ -I.\frame\1m\ -I.\frame\1f\ -I.\frame\1\ -I.\frame\include -IC:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\include\windows-x86_64
#                   [COMMAND] C:\MinGW\bin\clang.exe -c C:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\config\piledriver\bli_cntx_init_piledriver.c -o C:\Users\devid\AppData\Local\Temp\tmpd3ag3zpf\bli_cntx_init_piledriver.o -O2 -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.9.0" -DBLIS_IS_BUILDING_LIBRARY -Iinclude\windows-x86_64 -I.\frame\3\ -I.\frame\1m\ -I.\frame\1f\ -I.\frame\1\ -I.\frame\include -IC:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\include\windows-x86_64
#                   [COMMAND] C:\MinGW\bin\clang.exe -c C:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\config\sandybridge\bli_cntx_init_sandybridge.c -o C:\Users\devid\AppData\Local\Temp\tmpd3ag3zpf\bli_cntx_init_sandybridge.o -O2 -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.9.0" -DBLIS_IS_BUILDING_LIBRARY -Iinclude\windows-x86_64 -I.\frame\3\ -I.\frame\1m\ -I.\frame\1f\ -I.\frame\1\ -I.\frame\include -IC:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\include\windows-x86_64
#                   [COMMAND] C:\MinGW\bin\clang.exe -c C:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\config\skx\bli_cntx_init_skx.c -o C:\Users\devid\AppData\Local\Temp\tmpd3ag3zpf\bli_cntx_init_skx.o -O2 -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.9.0" -DBLIS_IS_BUILDING_LIBRARY -Iinclude\windows-x86_64 -I.\frame\3\ -I.\frame\1m\ -I.\frame\1f\ -I.\frame\1\ -I.\frame\include -IC:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\include\windows-x86_64
#                   [COMMAND] C:\MinGW\bin\clang.exe -c C:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\config\steamroller\bli_cntx_init_steamroller.c -o C:\Users\devid\AppData\Local\Temp\tmpd3ag3zpf\bli_cntx_init_steamroller.o -O2 -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.9.0" -DBLIS_IS_BUILDING_LIBRARY -Iinclude\windows-x86_64 -I.\frame\3\ -I.\frame\1m\ -I.\frame\1f\ -I.\frame\1\ -I.\frame\include -IC:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\include\windows-x86_64
#                   [COMMAND] C:\MinGW\bin\clang.exe -c C:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\config\zen\bli_cntx_init_zen.c -o C:\Users\devid\AppData\Local\Temp\tmpd3ag3zpf\bli_cntx_init_zen.o -O2 -fomit-frame-pointer -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.9.0" -DBLIS_IS_BUILDING_LIBRARY -Iinclude\windows-x86_64 -I.\frame\3\ -I.\frame\1m\ -I.\frame\1f\ -I.\frame\1\ -I.\frame\include -IC:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\include\windows-x86_64
#                   [COMMAND] C:\MinGW\bin\clang.exe -c C:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\config\zen2\bli_cntx_init_zen2.c -o C:\Users\devid\AppData\Local\Temp\tmpd3ag3zpf\bli_cntx_init_zen2.o -O2 -fomit-frame-pointer -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.9.0" -DBLIS_IS_BUILDING_LIBRARY -Iinclude\windows-x86_64 -I.\frame\3\ -I.\frame\1m\ -I.\frame\1f\ -I.\frame\1\ -I.\frame\include -IC:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\include\windows-x86_64
#                   [COMMAND] C:\MinGW\bin\clang.exe -c C:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\config\zen3\bli_cntx_init_zen3.c -o C:\Users\devid\AppData\Local\Temp\tmpd3ag3zpf\bli_cntx_init_zen3.o -O3 -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.9.0" -DBLIS_IS_BUILDING_LIBRARY -Iinclude\windows-x86_64 -I.\frame\3\ -I.\frame\1m\ -I.\frame\1f\ -I.\frame\1\ -I.\frame\include -IC:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\include\windows-x86_64
#                   [COMMAND] C:\MinGW\bin\clang.exe -c C:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\kernels\skx\3\bli_dgemm_skx_asm_16x12_l2.c -o C:\Users\devid\AppData\Local\Temp\tmpd3ag3zpf\bli_dgemm_skx_asm_16x12_l2.o -O2 -O3 -fomit-frame-pointer -mavx512f -mavx512dq -mavx512bw -mavx512vl -mfpmath=sse -march=haswell -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.9.0" -DBLIS_IS_BUILDING_LIBRARY -Iinclude\windows-x86_64 -I.\frame\3\ -I.\frame\1m\ -I.\frame\1f\ -I.\frame\1\ -I.\frame\include -IC:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\include\windows-x86_64
#                   [COMMAND] C:\MinGW\bin\clang.exe -c C:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\kernels\skx\3\bli_dgemm_skx_asm_16x14.c -o C:\Users\devid\AppData\Local\Temp\tmpd3ag3zpf\bli_dgemm_skx_asm_16x14.o -O2 -O3 -fomit-frame-pointer -mavx512f -mavx512dq -mavx512bw -mavx512vl -mfpmath=sse -march=haswell -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.9.0" -DBLIS_IS_BUILDING_LIBRARY -Iinclude\windows-x86_64 -I.\frame\3\ -I.\frame\1m\ -I.\frame\1f\ -I.\frame\1\ -I.\frame\include -IC:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\include\windows-x86_64
#                   [COMMAND] C:\MinGW\bin\clang.exe -c C:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\kernels\skx\3\bli_sgemm_skx_asm_32x12_l2.c -o C:\Users\devid\AppData\Local\Temp\tmpd3ag3zpf\bli_sgemm_skx_asm_32x12_l2.o -O2 -O3 -fomit-frame-pointer -mavx512f -mavx512dq -mavx512bw -mavx512vl -mfpmath=sse -march=haswell -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.9.0" -DBLIS_IS_BUILDING_LIBRARY -Iinclude\windows-x86_64 -I.\frame\3\ -I.\frame\1m\ -I.\frame\1f\ -I.\frame\1\ -I.\frame\include -IC:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\include\windows-x86_64
#                   [COMMAND] C:\MinGW\bin\clang.exe -c C:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\kernels\knl\1m\bli_dpackm_knl_asm_24x8.c -o C:\Users\devid\AppData\Local\Temp\tmpd3ag3zpf\bli_dpackm_knl_asm_24x8.o -O2 -O3 -mavx512f -mavx512pf -mfpmath=sse -march=knl -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.9.0" -DBLIS_IS_BUILDING_LIBRARY -Iinclude\windows-x86_64 -I.\frame\3\ -I.\frame\1m\ -I.\frame\1f\ -I.\frame\1\ -I.\frame\include -IC:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\include\windows-x86_64
#                   [COMMAND] C:\MinGW\bin\clang.exe -c C:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\kernels\knl\1m\bli_spackm_knl_asm_24x16.c -o C:\Users\devid\AppData\Local\Temp\tmpd3ag3zpf\bli_spackm_knl_asm_24x16.o -O2 -O3 -mavx512f -mavx512pf -mfpmath=sse -march=knl -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.9.0" -DBLIS_IS_BUILDING_LIBRARY -Iinclude\windows-x86_64 -I.\frame\3\ -I.\frame\1m\ -I.\frame\1f\ -I.\frame\1\ -I.\frame\include -IC:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\include\windows-x86_64
#                   [COMMAND] C:\MinGW\bin\clang.exe -c C:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\kernels\knl\3\bli_dgemm_knl_asm_24x8.c -o C:\Users\devid\AppData\Local\Temp\tmpd3ag3zpf\bli_dgemm_knl_asm_24x8.o -O2 -O3 -mavx512f -mavx512pf -mfpmath=sse -march=knl -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.9.0" -DBLIS_IS_BUILDING_LIBRARY -Iinclude\windows-x86_64 -I.\frame\3\ -I.\frame\1m\ -I.\frame\1f\ -I.\frame\1\ -I.\frame\include -IC:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\include\windows-x86_64
#                   [COMMAND] C:\MinGW\bin\clang.exe -c C:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\kernels\knl\3\bli_sgemm_knl_asm_24x16.c -o C:\Users\devid\AppData\Local\Temp\tmpd3ag3zpf\bli_sgemm_knl_asm_24x16.o -O2 -O3 -mavx512f -mavx512pf -mfpmath=sse -march=knl -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.9.0" -DBLIS_IS_BUILDING_LIBRARY -Iinclude\windows-x86_64 -I.\frame\3\ -I.\frame\1m\ -I.\frame\1f\ -I.\frame\1\ -I.\frame\include -IC:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\include\windows-x86_64
#                   [COMMAND] C:\MinGW\bin\clang.exe -c C:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\kernels\sandybridge\3\bli_gemm_sandybridge_asm_d8x4.c -o C:\Users\devid\AppData\Local\Temp\tmpd3ag3zpf\bli_gemm_sandybridge_asm_d8x4.o -O2 -O3 -mavx -mfpmath=sse -march=sandybridge -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.9.0" -DBLIS_IS_BUILDING_LIBRARY -Iinclude\windows-x86_64 -I.\frame\3\ -I.\frame\1m\ -I.\frame\1f\ -I.\frame\1\ -I.\frame\include -IC:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\include\windows-x86_64
#                   [COMMAND] C:\MinGW\bin\clang.exe -c C:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\kernels\sandybridge\3\bli_gemm_sandybridge_int_d8x4.c -o C:\Users\devid\AppData\Local\Temp\tmpd3ag3zpf\bli_gemm_sandybridge_int_d8x4.o -O2 -O3 -mavx -mfpmath=sse -march=sandybridge -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.9.0" -DBLIS_IS_BUILDING_LIBRARY -Iinclude\windows-x86_64 -I.\frame\3\ -I.\frame\1m\ -I.\frame\1f\ -I.\frame\1\ -I.\frame\include -IC:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\include\windows-x86_64
#                   [COMMAND] C:\MinGW\bin\clang.exe -c C:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\kernels\penryn\1\bli_axpyv_penryn_int.c -o C:\Users\devid\AppData\Local\Temp\tmpd3ag3zpf\bli_axpyv_penryn_int.o -O2 -O3 -mssse3 -mfpmath=sse -march=core2 -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.9.0" -DBLIS_IS_BUILDING_LIBRARY -Iinclude\windows-x86_64 -I.\frame\3\ -I.\frame\1m\ -I.\frame\1f\ -I.\frame\1\ -I.\frame\include -IC:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\include\windows-x86_64
#                   [COMMAND] C:\MinGW\bin\clang.exe -c C:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\kernels\penryn\1\bli_dotv_penryn_int.c -o C:\Users\devid\AppData\Local\Temp\tmpd3ag3zpf\bli_dotv_penryn_int.o -O2 -O3 -mssse3 -mfpmath=sse -march=core2 -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.9.0" -DBLIS_IS_BUILDING_LIBRARY -Iinclude\windows-x86_64 -I.\frame\3\ -I.\frame\1m\ -I.\frame\1f\ -I.\frame\1\ -I.\frame\include -IC:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\include\windows-x86_64
#                   [COMMAND] C:\MinGW\bin\clang.exe -c C:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\kernels\penryn\1f\bli_axpy2v_penryn_int.c -o C:\Users\devid\AppData\Local\Temp\tmpd3ag3zpf\bli_axpy2v_penryn_int.o -O2 -O3 -mssse3 -mfpmath=sse -march=core2 -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.9.0" -DBLIS_IS_BUILDING_LIBRARY -Iinclude\windows-x86_64 -I.\frame\3\ -I.\frame\1m\ -I.\frame\1f\ -I.\frame\1\ -I.\frame\include -IC:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\include\windows-x86_64
#                   [COMMAND] C:\MinGW\bin\clang.exe -c C:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\kernels\penryn\1f\bli_axpyf_penryn_int.c -o C:\Users\devid\AppData\Local\Temp\tmpd3ag3zpf\bli_axpyf_penryn_int.o -O2 -O3 -mssse3 -mfpmath=sse -march=core2 -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.9.0" -DBLIS_IS_BUILDING_LIBRARY -Iinclude\windows-x86_64 -I.\frame\3\ -I.\frame\1m\ -I.\frame\1f\ -I.\frame\1\ -I.\frame\include -IC:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\include\windows-x86_64
#                   [COMMAND] C:\MinGW\bin\clang.exe -c C:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\kernels\penryn\1f\bli_dotaxpyv_penryn_int.c -o C:\Users\devid\AppData\Local\Temp\tmpd3ag3zpf\bli_dotaxpyv_penryn_int.o -O2 -O3 -mssse3 -mfpmath=sse -march=core2 -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.9.0" -DBLIS_IS_BUILDING_LIBRARY -Iinclude\windows-x86_64 -I.\frame\3\ -I.\frame\1m\ -I.\frame\1f\ -I.\frame\1\ -I.\frame\include -IC:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\include\windows-x86_64
#                   [COMMAND] C:\MinGW\bin\clang.exe -c C:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\kernels\penryn\1f\bli_dotxaxpyf_penryn_int.c -o C:\Users\devid\AppData\Local\Temp\tmpd3ag3zpf\bli_dotxaxpyf_penryn_int.o -O2 -O3 -mssse3 -mfpmath=sse -march=core2 -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.9.0" -DBLIS_IS_BUILDING_LIBRARY -Iinclude\windows-x86_64 -I.\frame\3\ -I.\frame\1m\ -I.\frame\1f\ -I.\frame\1\ -I.\frame\include -IC:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\include\windows-x86_64
#                   [COMMAND] C:\MinGW\bin\clang.exe -c C:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\kernels\penryn\1f\bli_dotxf_penryn_int.c -o C:\Users\devid\AppData\Local\Temp\tmpd3ag3zpf\bli_dotxf_penryn_int.o -O2 -O3 -mssse3 -mfpmath=sse -march=core2 -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.9.0" -DBLIS_IS_BUILDING_LIBRARY -Iinclude\windows-x86_64 -I.\frame\3\ -I.\frame\1m\ -I.\frame\1f\ -I.\frame\1\ -I.\frame\include -IC:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\include\windows-x86_64
#                   [COMMAND] C:\MinGW\bin\clang.exe -c C:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\kernels\penryn\3\bli_gemm_penryn_asm_d4x4.c -o C:\Users\devid\AppData\Local\Temp\tmpd3ag3zpf\bli_gemm_penryn_asm_d4x4.o -O2 -O3 -mssse3 -mfpmath=sse -march=core2 -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.9.0" -DBLIS_IS_BUILDING_LIBRARY -Iinclude\windows-x86_64 -I.\frame\3\ -I.\frame\1m\ -I.\frame\1f\ -I.\frame\1\ -I.\frame\include -IC:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\include\windows-x86_64
#                   [COMMAND] C:\MinGW\bin\clang.exe -c C:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\kernels\penryn\3\bli_gemmtrsm_l_penryn_asm_d4x4.c -o C:\Users\devid\AppData\Local\Temp\tmpd3ag3zpf\bli_gemmtrsm_l_penryn_asm_d4x4.o -O2 -O3 -mssse3 -mfpmath=sse -march=core2 -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.9.0" -DBLIS_IS_BUILDING_LIBRARY -Iinclude\windows-x86_64 -I.\frame\3\ -I.\frame\1m\ -I.\frame\1f\ -I.\frame\1\ -I.\frame\include -IC:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\include\windows-x86_64
#                   [COMMAND] C:\MinGW\bin\clang.exe -c C:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\kernels\penryn\3\bli_gemmtrsm_u_penryn_asm_d4x4.c -o C:\Users\devid\AppData\Local\Temp\tmpd3ag3zpf\bli_gemmtrsm_u_penryn_asm_d4x4.o -O2 -O3 -mssse3 -mfpmath=sse -march=core2 -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.9.0" -DBLIS_IS_BUILDING_LIBRARY -Iinclude\windows-x86_64 -I.\frame\3\ -I.\frame\1m\ -I.\frame\1f\ -I.\frame\1\ -I.\frame\include -IC:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\include\windows-x86_64
#                   [COMMAND] C:\MinGW\bin\clang.exe -c C:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\kernels\penryn\3\bli_trsm_l_penryn_asm_d4x4.c -o C:\Users\devid\AppData\Local\Temp\tmpd3ag3zpf\bli_trsm_l_penryn_asm_d4x4.o -O2 -O3 -mssse3 -mfpmath=sse -march=core2 -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.9.0" -DBLIS_IS_BUILDING_LIBRARY -Iinclude\windows-x86_64 -I.\frame\3\ -I.\frame\1m\ -I.\frame\1f\ -I.\frame\1\ -I.\frame\include -IC:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\include\windows-x86_64
#                   [COMMAND] C:\MinGW\bin\clang.exe -c C:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\kernels\penryn\3\bli_trsm_u_penryn_asm_d4x4.c -o C:\Users\devid\AppData\Local\Temp\tmpd3ag3zpf\bli_trsm_u_penryn_asm_d4x4.o -O2 -O3 -mssse3 -mfpmath=sse -march=core2 -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.9.0" -DBLIS_IS_BUILDING_LIBRARY -Iinclude\windows-x86_64 -I.\frame\3\ -I.\frame\1m\ -I.\frame\1f\ -I.\frame\1\ -I.\frame\include -IC:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\include\windows-x86_64
#                   [COMMAND] C:\MinGW\bin\clang.exe -c C:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\kernels\haswell\1m\bli_packm_haswell_asm_c3xk.c -o C:\Users\devid\AppData\Local\Temp\tmpd3ag3zpf\bli_packm_haswell_asm_c3xk.o -O2 -O3 -fomit-frame-pointer -mavx2 -mfma -mfpmath=sse -march=haswell -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.9.0" -DBLIS_IS_BUILDING_LIBRARY -Iinclude\windows-x86_64 -I.\frame\3\ -I.\frame\1m\ -I.\frame\1f\ -I.\frame\1\ -I.\frame\include -IC:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\include\windows-x86_64
#                   [COMMAND] C:\MinGW\bin\clang.exe -c C:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\kernels\haswell\1m\bli_packm_haswell_asm_c8xk.c -o C:\Users\devid\AppData\Local\Temp\tmpd3ag3zpf\bli_packm_haswell_asm_c8xk.o -O2 -O3 -fomit-frame-pointer -mavx2 -mfma -mfpmath=sse -march=haswell -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.9.0" -DBLIS_IS_BUILDING_LIBRARY -Iinclude\windows-x86_64 -I.\frame\3\ -I.\frame\1m\ -I.\frame\1f\ -I.\frame\1\ -I.\frame\include -IC:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\include\windows-x86_64
#                   [COMMAND] C:\MinGW\bin\clang.exe -c C:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\kernels\haswell\1m\bli_packm_haswell_asm_d6xk.c -o C:\Users\devid\AppData\Local\Temp\tmpd3ag3zpf\bli_packm_haswell_asm_d6xk.o -O2 -O3 -fomit-frame-pointer -mavx2 -mfma -mfpmath=sse -march=haswell -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.9.0" -DBLIS_IS_BUILDING_LIBRARY -Iinclude\windows-x86_64 -I.\frame\3\ -I.\frame\1m\ -I.\frame\1f\ -I.\frame\1\ -I.\frame\include -IC:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\include\windows-x86_64
#                   [COMMAND] C:\MinGW\bin\clang.exe -c C:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\kernels\haswell\1m\bli_packm_haswell_asm_d8xk.c -o C:\Users\devid\AppData\Local\Temp\tmpd3ag3zpf\bli_packm_haswell_asm_d8xk.o -O2 -O3 -fomit-frame-pointer -mavx2 -mfma -mfpmath=sse -march=haswell -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.9.0" -DBLIS_IS_BUILDING_LIBRARY -Iinclude\windows-x86_64 -I.\frame\3\ -I.\frame\1m\ -I.\frame\1f\ -I.\frame\1\ -I.\frame\include -IC:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\include\windows-x86_64
#                   [COMMAND] C:\MinGW\bin\clang.exe -c C:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\kernels\haswell\1m\bli_packm_haswell_asm_s16xk.c -o C:\Users\devid\AppData\Local\Temp\tmpd3ag3zpf\bli_packm_haswell_asm_s16xk.o -O2 -O3 -fomit-frame-pointer -mavx2 -mfma -mfpmath=sse -march=haswell -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.9.0" -DBLIS_IS_BUILDING_LIBRARY -Iinclude\windows-x86_64 -I.\frame\3\ -I.\frame\1m\ -I.\frame\1f\ -I.\frame\1\ -I.\frame\include -IC:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\include\windows-x86_64
#                   [COMMAND] C:\MinGW\bin\clang.exe -c C:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\kernels\haswell\1m\bli_packm_haswell_asm_s6xk.c -o C:\Users\devid\AppData\Local\Temp\tmpd3ag3zpf\bli_packm_haswell_asm_s6xk.o -O2 -O3 -fomit-frame-pointer -mavx2 -mfma -mfpmath=sse -march=haswell -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.9.0" -DBLIS_IS_BUILDING_LIBRARY -Iinclude\windows-x86_64 -I.\frame\3\ -I.\frame\1m\ -I.\frame\1f\ -I.\frame\1\ -I.\frame\include -IC:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\include\windows-x86_64
#                   [COMMAND] C:\MinGW\bin\clang.exe -c C:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\kernels\haswell\1m\bli_packm_haswell_asm_z3xk.c -o C:\Users\devid\AppData\Local\Temp\tmpd3ag3zpf\bli_packm_haswell_asm_z3xk.o -O2 -O3 -fomit-frame-pointer -mavx2 -mfma -mfpmath=sse -march=haswell -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.9.0" -DBLIS_IS_BUILDING_LIBRARY -Iinclude\windows-x86_64 -I.\frame\3\ -I.\frame\1m\ -I.\frame\1f\ -I.\frame\1\ -I.\frame\include -IC:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\include\windows-x86_64
#                   [COMMAND] C:\MinGW\bin\clang.exe -c C:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\kernels\haswell\1m\bli_packm_haswell_asm_z4xk.c -o C:\Users\devid\AppData\Local\Temp\tmpd3ag3zpf\bli_packm_haswell_asm_z4xk.o -O2 -O3 -fomit-frame-pointer -mavx2 -mfma -mfpmath=sse -march=haswell -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.9.0" -DBLIS_IS_BUILDING_LIBRARY -Iinclude\windows-x86_64 -I.\frame\3\ -I.\frame\1m\ -I.\frame\1f\ -I.\frame\1\ -I.\frame\include -IC:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\include\windows-x86_64
#                   [COMMAND] C:\MinGW\bin\clang.exe -c C:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\kernels\haswell\3\bli_gemm_haswell_asm_d6x8.c -o C:\Users\devid\AppData\Local\Temp\tmpd3ag3zpf\bli_gemm_haswell_asm_d6x8.o -O2 -O3 -fomit-frame-pointer -mavx2 -mfma -mfpmath=sse -march=haswell -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.9.0" -DBLIS_IS_BUILDING_LIBRARY -Iinclude\windows-x86_64 -I.\frame\3\ -I.\frame\1m\ -I.\frame\1f\ -I.\frame\1\ -I.\frame\include -IC:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\include\windows-x86_64
#                   [COMMAND] C:\MinGW\bin\clang.exe -c C:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\kernels\haswell\3\bli_gemm_haswell_asm_d8x6.c -o C:\Users\devid\AppData\Local\Temp\tmpd3ag3zpf\bli_gemm_haswell_asm_d8x6.o -O2 -O3 -fomit-frame-pointer -mavx2 -mfma -mfpmath=sse -march=haswell -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.9.0" -DBLIS_IS_BUILDING_LIBRARY -Iinclude\windows-x86_64 -I.\frame\3\ -I.\frame\1m\ -I.\frame\1f\ -I.\frame\1\ -I.\frame\include -IC:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\include\windows-x86_64
#                   [COMMAND] C:\MinGW\bin\clang.exe -c C:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\kernels\haswell\3\bli_gemmtrsm_l_haswell_asm_d6x8.c -o C:\Users\devid\AppData\Local\Temp\tmpd3ag3zpf\bli_gemmtrsm_l_haswell_asm_d6x8.o -O2 -O3 -fomit-frame-pointer -mavx2 -mfma -mfpmath=sse -march=haswell -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.9.0" -DBLIS_IS_BUILDING_LIBRARY -Iinclude\windows-x86_64 -I.\frame\3\ -I.\frame\1m\ -I.\frame\1f\ -I.\frame\1\ -I.\frame\include -IC:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\include\windows-x86_64
#                   [COMMAND] C:\MinGW\bin\clang.exe -c C:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\kernels\haswell\3\bli_gemmtrsm_u_haswell_asm_d6x8.c -o C:\Users\devid\AppData\Local\Temp\tmpd3ag3zpf\bli_gemmtrsm_u_haswell_asm_d6x8.o -O2 -O3 -fomit-frame-pointer -mavx2 -mfma -mfpmath=sse -march=haswell -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.9.0" -DBLIS_IS_BUILDING_LIBRARY -Iinclude\windows-x86_64 -I.\frame\3\ -I.\frame\1m\ -I.\frame\1f\ -I.\frame\1\ -I.\frame\include -IC:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\include\windows-x86_64
#                   [COMMAND] C:\MinGW\bin\clang.exe -c C:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\kernels\haswell\3\sup\bli_gemmsup_rd_haswell_asm_d6x8m.c -o C:\Users\devid\AppData\Local\Temp\tmpd3ag3zpf\bli_gemmsup_rd_haswell_asm_d6x8m.o -O2 -O3 -fomit-frame-pointer -mavx2 -mfma -mfpmath=sse -march=haswell -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.9.0" -DBLIS_IS_BUILDING_LIBRARY -Iinclude\windows-x86_64 -I.\frame\3\ -I.\frame\1m\ -I.\frame\1f\ -I.\frame\1\ -I.\frame\include -IC:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\include\windows-x86_64
#                   [COMMAND] C:\MinGW\bin\clang.exe -c C:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\kernels\haswell\3\sup\bli_gemmsup_rd_haswell_asm_d6x8n.c -o C:\Users\devid\AppData\Local\Temp\tmpd3ag3zpf\bli_gemmsup_rd_haswell_asm_d6x8n.o -O2 -O3 -fomit-frame-pointer -mavx2 -mfma -mfpmath=sse -march=haswell -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.9.0" -DBLIS_IS_BUILDING_LIBRARY -Iinclude\windows-x86_64 -I.\frame\3\ -I.\frame\1m\ -I.\frame\1f\ -I.\frame\1\ -I.\frame\include -IC:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\include\windows-x86_64
#                   [COMMAND] C:\MinGW\bin\clang.exe -c C:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\kernels\haswell\3\sup\bli_gemmsup_rd_haswell_asm_s6x16m.c -o C:\Users\devid\AppData\Local\Temp\tmpd3ag3zpf\bli_gemmsup_rd_haswell_asm_s6x16m.o -O2 -O3 -fomit-frame-pointer -mavx2 -mfma -mfpmath=sse -march=haswell -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.9.0" -DBLIS_IS_BUILDING_LIBRARY -Iinclude\windows-x86_64 -I.\frame\3\ -I.\frame\1m\ -I.\frame\1f\ -I.\frame\1\ -I.\frame\include -IC:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\include\windows-x86_64
#                   [COMMAND] C:\MinGW\bin\clang.exe -c C:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\kernels\haswell\3\sup\bli_gemmsup_rd_haswell_asm_s6x16n.c -o C:\Users\devid\AppData\Local\Temp\tmpd3ag3zpf\bli_gemmsup_rd_haswell_asm_s6x16n.o -O2 -O3 -fomit-frame-pointer -mavx2 -mfma -mfpmath=sse -march=haswell -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.9.0" -DBLIS_IS_BUILDING_LIBRARY -Iinclude\windows-x86_64 -I.\frame\3\ -I.\frame\1m\ -I.\frame\1f\ -I.\frame\1\ -I.\frame\include -IC:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\include\windows-x86_64
#                   [COMMAND] C:\MinGW\bin\clang.exe -c C:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\kernels\haswell\3\sup\bli_gemmsup_rv_haswell_asm_d6x8m.c -o C:\Users\devid\AppData\Local\Temp\tmpd3ag3zpf\bli_gemmsup_rv_haswell_asm_d6x8m.o -O2 -O3 -fomit-frame-pointer -mavx2 -mfma -mfpmath=sse -march=haswell -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.9.0" -DBLIS_IS_BUILDING_LIBRARY -Iinclude\windows-x86_64 -I.\frame\3\ -I.\frame\1m\ -I.\frame\1f\ -I.\frame\1\ -I.\frame\include -IC:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\include\windows-x86_64
#                   [COMMAND] C:\MinGW\bin\clang.exe -c C:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\kernels\haswell\3\sup\bli_gemmsup_rv_haswell_asm_d6x8n.c -o C:\Users\devid\AppData\Local\Temp\tmpd3ag3zpf\bli_gemmsup_rv_haswell_asm_d6x8n.o -O2 -O3 -fomit-frame-pointer -mavx2 -mfma -mfpmath=sse -march=haswell -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.9.0" -DBLIS_IS_BUILDING_LIBRARY -Iinclude\windows-x86_64 -I.\frame\3\ -I.\frame\1m\ -I.\frame\1f\ -I.\frame\1\ -I.\frame\include -IC:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\include\windows-x86_64
#                   [COMMAND] C:\MinGW\bin\clang.exe -c C:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\kernels\haswell\3\sup\bli_gemmsup_rv_haswell_asm_s6x16m.c -o C:\Users\devid\AppData\Local\Temp\tmpd3ag3zpf\bli_gemmsup_rv_haswell_asm_s6x16m.o -O2 -O3 -fomit-frame-pointer -mavx2 -mfma -mfpmath=sse -march=haswell -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.9.0" -DBLIS_IS_BUILDING_LIBRARY -Iinclude\windows-x86_64 -I.\frame\3\ -I.\frame\1m\ -I.\frame\1f\ -I.\frame\1\ -I.\frame\include -IC:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\include\windows-x86_64
#                   [COMMAND] C:\MinGW\bin\clang.exe -c C:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\kernels\haswell\3\sup\bli_gemmsup_rv_haswell_asm_s6x16n.c -o C:\Users\devid\AppData\Local\Temp\tmpd3ag3zpf\bli_gemmsup_rv_haswell_asm_s6x16n.o -O2 -O3 -fomit-frame-pointer -mavx2 -mfma -mfpmath=sse -march=haswell -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.9.0" -DBLIS_IS_BUILDING_LIBRARY -Iinclude\windows-x86_64 -I.\frame\3\ -I.\frame\1m\ -I.\frame\1f\ -I.\frame\1\ -I.\frame\include -IC:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\include\windows-x86_64
#                   [COMMAND] C:\MinGW\bin\clang.exe -c C:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\kernels\haswell\3\sup\d6x8\bli_gemmsup_r_haswell_ref_dMx1.c -o C:\Users\devid\AppData\Local\Temp\tmpd3ag3zpf\bli_gemmsup_r_haswell_ref_dMx1.o -O2 -O3 -fomit-frame-pointer -mavx2 -mfma -mfpmath=sse -march=haswell -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.9.0" -DBLIS_IS_BUILDING_LIBRARY -Iinclude\windows-x86_64 -I.\frame\3\ -I.\frame\1m\ -I.\frame\1f\ -I.\frame\1\ -I.\frame\include -IC:\Users\devid\AppData\Local\Temp\pip-install-l8m9h_me\blis_531771772b80468cbdda57e58e581aa3\blis\_src\include\windows-x86_64
# ...
#                          |                                                                                                            ^~~~~~~~~
#                   blis\cy.c:21272:299: note: passing argument to parameter '__pyx_v_a' here
#                    21272 | static void __pyx_fuse_1__pyx_f_4blis_2cy_gemm(enum __pyx_t_4blis_2cy_trans_t __pyx_v_trans_a, enum __pyx_t_4blis_2cy_trans_t __pyx_v_trans_b, __pyx_t_4blis_2cy_dim_t __pyx_v_m, __pyx_t_4blis_2cy_dim_t __pyx_v_n, __pyx_t_4blis_2cy_dim_t __pyx_v_k, double __pyx_v_alpha, __pyx_t_4blis_2cy_doubles_t __pyx_v_a, __pyx_t_4blis_2cy_inc_t __pyx_v_rsa, __pyx_t_4blis_2cy_inc_t __pyx_v_csa, __pyx_t_4blis_2cy_doubles_t __pyx_v_b, __pyx_t_4blis_2cy_inc_t __pyx_v_rsb, __pyx_t_4blis_2cy_inc_t __pyx_v_csb, double __pyx_v_beta, __pyx_t_4blis_2cy_doubles_t __pyx_v_c, __pyx_t_4blis_2cy_inc_t __pyx_v_rsc, __pyx_t_4blis_2cy_inc_t __pyx_v_csc) {
#                          |                                                                                                                                                                                                                                                                                                           ^
#                   blis\cy.c:24347:135: warning: passing 'const double *' to parameter of type '__pyx_t_4blis_2cy_doubles_t' (aka 'double *') discards qualifiers [-Wincompatible-pointer-types-discards-qualifiers]
#                    24347 |   __pyx_fuse_1__pyx_f_4blis_2cy_gemm(__pyx_t_1, __pyx_t_2, __pyx_v_M, __pyx_v_N, __pyx_v_K, __pyx_v_alpha, __pyx_v_A, __pyx_v_lda, 1, __pyx_v_B, __pyx_v_ldb, 1, __pyx_v_beta, __pyx_v_C, __pyx_v_ldc, 1);
#                          |                                                                                                                                       ^~~~~~~~~
#                   blis\cy.c:21272:412: note: passing argument to parameter '__pyx_v_b' here
#                    21272 | static void __pyx_fuse_1__pyx_f_4blis_2cy_gemm(enum __pyx_t_4blis_2cy_trans_t __pyx_v_trans_a, enum __pyx_t_4blis_2cy_trans_t __pyx_v_trans_b, __pyx_t_4blis_2cy_dim_t __pyx_v_m, __pyx_t_4blis_2cy_dim_t __pyx_v_n, __pyx_t_4blis_2cy_dim_t __pyx_v_k, double __pyx_v_alpha, __pyx_t_4blis_2cy_doubles_t __pyx_v_a, __pyx_t_4blis_2cy_inc_t __pyx_v_rsa, __pyx_t_4blis_2cy_inc_t __pyx_v_csa, __pyx_t_4blis_2cy_doubles_t __pyx_v_b, __pyx_t_4blis_2cy_inc_t __pyx_v_rsb, __pyx_t_4blis_2cy_inc_t __pyx_v_csb, double __pyx_v_beta, __pyx_t_4blis_2cy_doubles_t __pyx_v_c, __pyx_t_4blis_2cy_inc_t __pyx_v_rsc, __pyx_t_4blis_2cy_inc_t __pyx_v_csc) {
#                          |                                                                                                                                                                                                                                                                                                                                                                                                                            ^
#                   blis\cy.c:24405:108: warning: passing 'const float *' to parameter of type '__pyx_t_4blis_2cy_floats_t' (aka 'float *') discards qualifiers [-Wincompatible-pointer-types-discards-qualifiers]
#                    24405 |   __pyx_fuse_0__pyx_f_4blis_2cy_gemm(__pyx_t_1, __pyx_t_2, __pyx_v_M, __pyx_v_N, __pyx_v_K, __pyx_v_alpha, __pyx_v_A, __pyx_v_lda, 1, __pyx_v_B, __pyx_v_ldb, 1, __pyx_v_beta, __pyx_v_C, __pyx_v_ldc, 1);
#                          |                                                                                                            ^~~~~~~~~
#                   blis\cy.c:21210:298: note: passing argument to parameter '__pyx_v_a' here
#                    21210 | static void __pyx_fuse_0__pyx_f_4blis_2cy_gemm(enum __pyx_t_4blis_2cy_trans_t __pyx_v_trans_a, enum __pyx_t_4blis_2cy_trans_t __pyx_v_trans_b, __pyx_t_4blis_2cy_dim_t __pyx_v_m, __pyx_t_4blis_2cy_dim_t __pyx_v_n, __pyx_t_4blis_2cy_dim_t __pyx_v_k, double __pyx_v_alpha, __pyx_t_4blis_2cy_floats_t __pyx_v_a, __pyx_t_4blis_2cy_inc_t __pyx_v_rsa, __pyx_t_4blis_2cy_inc_t __pyx_v_csa, __pyx_t_4blis_2cy_floats_t __pyx_v_b, __pyx_t_4blis_2cy_inc_t __pyx_v_rsb, __pyx_t_4blis_2cy_inc_t __pyx_v_csb, double __pyx_v_beta, __pyx_t_4blis_2cy_floats_t __pyx_v_c, __pyx_t_4blis_2cy_inc_t __pyx_v_rsc, __pyx_t_4blis_2cy_inc_t __pyx_v_csc) {
#                          |                                                                                                                                                                                                                                                                                                          ^
#                   blis\cy.c:24405:135: warning: passing 'const float *' to parameter of type '__pyx_t_4blis_2cy_floats_t' (aka 'float *') discards qualifiers [-Wincompatible-pointer-types-discards-qualifiers]
#                    24405 |   __pyx_fuse_0__pyx_f_4blis_2cy_gemm(__pyx_t_1, __pyx_t_2, __pyx_v_M, __pyx_v_N, __pyx_v_K, __pyx_v_alpha, __pyx_v_A, __pyx_v_lda, 1, __pyx_v_B, __pyx_v_ldb, 1, __pyx_v_beta, __pyx_v_C, __pyx_v_ldc, 1);
#                          |                                                                                                                                       ^~~~~~~~~
#                   blis\cy.c:21210:410: note: passing argument to parameter '__pyx_v_b' here
#                    21210 | static void __pyx_fuse_0__pyx_f_4blis_2cy_gemm(enum __pyx_t_4blis_2cy_trans_t __pyx_v_trans_a, enum __pyx_t_4blis_2cy_trans_t __pyx_v_trans_b, __pyx_t_4blis_2cy_dim_t __pyx_v_m, __pyx_t_4blis_2cy_dim_t __pyx_v_n, __pyx_t_4blis_2cy_dim_t __pyx_v_k, double __pyx_v_alpha, __pyx_t_4blis_2cy_floats_t __pyx_v_a, __pyx_t_4blis_2cy_inc_t __pyx_v_rsa, __pyx_t_4blis_2cy_inc_t __pyx_v_csa, __pyx_t_4blis_2cy_floats_t __pyx_v_b, __pyx_t_4blis_2cy_inc_t __pyx_v_rsb, __pyx_t_4blis_2cy_inc_t __pyx_v_csb, double __pyx_v_beta, __pyx_t_4blis_2cy_floats_t __pyx_v_c, __pyx_t_4blis_2cy_inc_t __pyx_v_rsc, __pyx_t_4blis_2cy_inc_t __pyx_v_csc) {
#                          |                                                                                                                                                                                                                                                                                                                                                                                                                          ^
#                   blis\cy.c:24435:99: warning: passing 'const float *' to parameter of type '__pyx_t_4blis_2cy_floats_t' (aka 'float *') discards qualifiers [-Wincompatible-pointer-types-discards-qualifiers]
#                    24435 |   __pyx_fuse_0_0__pyx_f_4blis_2cy_axpyv(__pyx_e_4blis_2cy_NO_CONJUGATE, __pyx_v_N, __pyx_v_alpha, __pyx_v_X, __pyx_v_incX, __pyx_v_Y, __pyx_v_incY);
#                          |                                                                                                   ^~~~~~~~~
#                   blis\cy.c:22346:179: note: passing argument to parameter '__pyx_v_x' here
#                    22346 | static void __pyx_fuse_0_0__pyx_f_4blis_2cy_axpyv(enum __pyx_t_4blis_2cy_conj_t __pyx_v_conjx, __pyx_t_4blis_2cy_dim_t __pyx_v_m, float __pyx_v_alpha, __pyx_t_4blis_2cy_floats_t __pyx_v_x, __pyx_t_4blis_2cy_inc_t __pyx_v_incx, __pyx_t_4blis_2cy_floats_t __pyx_v_y, __pyx_t_4blis_2cy_inc_t __pyx_v_incy) {
#                          |                                                                                                                                                                                   ^
#                   blis\cy.c:24465:99: warning: passing 'const double *' to parameter of type '__pyx_t_4blis_2cy_doubles_t' (aka 'double *') discards qualifiers [-Wincompatible-pointer-types-discards-qualifiers]
#                    24465 |   __pyx_fuse_1_1__pyx_f_4blis_2cy_axpyv(__pyx_e_4blis_2cy_NO_CONJUGATE, __pyx_v_N, __pyx_v_alpha, __pyx_v_X, __pyx_v_incX, __pyx_v_Y, __pyx_v_incY);
#                          |                                                                                                   ^~~~~~~~~
#                   blis\cy.c:22568:181: note: passing argument to parameter '__pyx_v_x' here
#                    22568 | static void __pyx_fuse_1_1__pyx_f_4blis_2cy_axpyv(enum __pyx_t_4blis_2cy_conj_t __pyx_v_conjx, __pyx_t_4blis_2cy_dim_t __pyx_v_m, double __pyx_v_alpha, __pyx_t_4blis_2cy_doubles_t __pyx_v_x, __pyx_t_4blis_2cy_inc_t __pyx_v_incx, __pyx_t_4blis_2cy_doubles_t __pyx_v_y, __pyx_t_4blis_2cy_inc_t __pyx_v_incy) {
#                          |                                                                                                                                                                                     ^
#                   6 warnings generated.
#                   C:\MinGW\bin\clang.exe -shared build\temp.win-amd64-cpython-313\Release\blis\cy.o z\bli_cntx_init_bulldozer.o z\bli_cntx_init_excavator.o z\bli_cntx_init_generic.o z\bli_cntx_init_haswell.o z\bli_cntx_init_knl.o z\bli_cntx_init_penryn.o z\bli_cntx_init_piledriver.o z\bli_cntx_init_sandybridge.o z\bli_cntx_init_skx.o z\bli_cntx_init_steamroller.o z\bli_cntx_init_zen.o z\bli_cntx_init_zen2.o z\bli_cntx_init_zen3.o z\bli_dgemm_skx_asm_16x12_l2.o z\bli_dgemm_skx_asm_16x14.o z\bli_sgemm_skx_asm_32x12_l2.o z\bli_dpackm_knl_asm_24x8.o z\bli_spackm_knl_asm_24x16.o z\bli_dgemm_knl_asm_24x8.o z\bli_sgemm_knl_asm_24x16.o z\bli_gemm_sandybridge_asm_d8x4.o z\bli_gemm_sandybridge_int_d8x4.o z\bli_axpyv_penryn_int.o z\bli_dotv_penryn_int.o z\bli_axpy2v_penryn_int.o z\bli_axpyf_penryn_int.o z\bli_dotaxpyv_penryn_int.o z\bli_dotxaxpyf_penryn_int.o z\bli_dotxf_penryn_int.o z\bli_gemm_penryn_asm_d4x4.o z\bli_gemmtrsm_l_penryn_asm_d4x4.o z\bli_gemmtrsm_u_penryn_asm_d4x4.o z\bli_trsm_l_penryn_asm_d4x4.o z\bli_trsm_u_penryn_asm_d4x4.o z\bli_packm_haswell_asm_c3xk.o z\bli_packm_haswell_asm_c8xk.o z\bli_packm_haswell_asm_d6xk.o z\bli_packm_haswell_asm_d8xk.o z\bli_packm_haswell_asm_s16xk.o z\bli_packm_haswell_asm_s6xk.o z\bli_packm_haswell_asm_z3xk.o z\bli_packm_haswell_asm_z4xk.o z\bli_gemm_haswell_asm_d6x8.o z\bli_gemm_haswell_asm_d8x6.o z\bli_gemmtrsm_l_haswell_asm_d6x8.o z\bli_gemmtrsm_u_haswell_asm_d6x8.o z\bli_gemmsup_rd_haswell_asm_d6x8m.o z\bli_gemmsup_rd_haswell_asm_d6x8n.o z\bli_gemmsup_rd_haswell_asm_s6x16m.o z\bli_gemmsup_rd_haswell_asm_s6x16n.o z\bli_gemmsup_rv_haswell_asm_d6x8m.o z\bli_gemmsup_rv_haswell_asm_d6x8n.o z\bli_gemmsup_rv_haswell_asm_s6x16m.o z\bli_gemmsup_rv_haswell_asm_s6x16n.o z\bli_gemmsup_r_haswell_ref_dMx1.o z\bli_gemmsup_rd_haswell_asm_dMx1.o z\bli_gemmsup_rd_haswell_asm_dMx2.o z\bli_gemmsup_rd_haswell_asm_dMx4.o z\bli_gemmsup_rd_haswell_asm_dMx8.o z\bli_gemmsup_rv_haswell_asm_dMx2.o z\bli_gemmsup_rv_haswell_asm_dMx4.o z\bli_gemmsup_rv_haswell_asm_dMx6.o z\bli_gemmsup_rv_haswell_asm_dMx8.o z\bli_gemmsup_r_haswell_ref_sMx1.o z\bli_gemmsup_rd_haswell_asm_sMx1.o z\bli_gemmsup_rd_haswell_asm_sMx12.o z\bli_gemmsup_rd_haswell_asm_sMx16.o z\bli_gemmsup_rd_haswell_asm_sMx2.o z\bli_gemmsup_rd_haswell_asm_sMx4.o z\bli_gemmsup_rd_haswell_asm_sMx8.o z\bli_gemmsup_rv_haswell_asm_sMx12.o z\bli_gemmsup_rv_haswell_asm_sMx16.o z\bli_gemmsup_rv_haswell_asm_sMx2.o z\bli_gemmsup_rv_haswell_asm_sMx4.o z\bli_gemmsup_rv_haswell_asm_sMx6.o z\bli_gemmsup_rv_haswell_asm_sMx8.o z\bli_amaxv_zen_int.o z\bli_axpyv_zen_int.o z\bli_axpyv_zen_int10.o z\bli_copyv_zen_int.o z\bli_dotv_zen_int.o z\bli_dotv_zen_int10.o z\bli_dotxv_zen_int.o z\bli_scalv_zen_int.o z\bli_scalv_zen_int10.o z\bli_setv_zen_int.o z\bli_swapv_zen_int8.o z\bli_axpyf_zen_int_4.o z\bli_axpyf_zen_int_5.o z\bli_axpyf_zen_int_8.o z\bli_dotxf_zen_int_8.o z\bli_gemm_small.o z\bli_gemmt_small.o z\bli_trsm_small.o z\bli_gemm_piledriver_asm_d8x3.o z\bli_gemm_bulldozer_asm_d4x6_fma4.o z\bli_cntx_skx_ref.o z\bli_addv_skx_ref.o z\bli_amaxv_skx_ref.o z\bli_axpbyv_skx_ref.o z\bli_axpyv_skx_ref.o z\bli_copyv_skx_ref.o z\bli_dotv_skx_ref.o z\bli_dotxv_skx_ref.o z\bli_invertv_skx_ref.o z\bli_scal2v_skx_ref.o z\bli_scalv_skx_ref.o z\bli_setv_skx_ref.o z\bli_subv_skx_ref.o z\bli_swapv_skx_ref.o z\bli_xpbyv_skx_ref.o z\bli_axpy2v_skx_ref.o z\bli_axpyf_skx_ref.o z\bli_dotaxpyv_skx_ref.o z\bli_dotxaxpyf_skx_ref.o z\bli_dotxf_skx_ref.o z\bli_packm_cxk_1er_skx_ref.o z\bli_packm_cxk_bb_skx_ref.o z\bli_packm_cxk_skx_ref.o z\bli_unpackm_cxk_skx_ref.o z\bli_gemm_skx_ref.o z\bli_gemmsup_skx_ref.o z\bli_gemmtrsm_skx_ref.o z\bli_trsm_skx_ref.o z\bli_gemmbb_skx_ref.o z\bli_gemmtrsmbb_skx_ref.o z\bli_trsmbb_skx_ref.o z\bli_gemm1m_skx_ref.o z\bli_gemmtrsm1m_skx_ref.o z\bli_trsm1m_skx_ref.o z\bli_cntx_knl_ref.o z\bli_addv_knl_ref.o z\bli_amaxv_knl_ref.o z\bli_axpbyv_knl_ref.o z\bli_axpyv_knl_ref.o z\bli_copyv_knl_ref.o z\bli_dotv_knl_ref.o z\bli_dotxv_knl_ref.o z\bli_invertv_knl_ref.o z\bli_scal2v_ ...
#                   C:/MinGW/bin/ld: z\bli_pthread.o:bli_pthread.c:(.text+0x1): undefined reference to `pthread_create'
#                   C:/MinGW/bin/ld: z\bli_pthread.o:bli_pthread.c:(.text+0x11): undefined reference to `pthread_join'
#                   C:/MinGW/bin/ld: z\bli_pthread.o:bli_pthread.c:(.text+0x21): undefined reference to `pthread_mutex_init'
#                   C:/MinGW/bin/ld: z\bli_pthread.o:bli_pthread.c:(.text+0x31): undefined reference to `pthread_mutex_destroy'
#                   C:/MinGW/bin/ld: z\bli_pthread.o:bli_pthread.c:(.text+0x41): undefined reference to `pthread_mutex_lock'
#                   C:/MinGW/bin/ld: z\bli_pthread.o:bli_pthread.c:(.text+0x51): undefined reference to `pthread_mutex_trylock'
#                   C:/MinGW/bin/ld: z\bli_pthread.o:bli_pthread.c:(.text+0x61): undefined reference to `pthread_mutex_unlock'
#                   C:/MinGW/bin/ld: z\bli_pthread.o:bli_pthread.c:(.text+0x71): undefined reference to `pthread_cond_init'
#                   C:/MinGW/bin/ld: z\bli_pthread.o:bli_pthread.c:(.text+0x81): undefined reference to `pthread_cond_destroy'
#                   C:/MinGW/bin/ld: z\bli_pthread.o:bli_pthread.c:(.text+0x91): undefined reference to `pthread_cond_wait'
#                   C:/MinGW/bin/ld: z\bli_pthread.o:bli_pthread.c:(.text+0xa1): undefined reference to `pthread_cond_broadcast'
#                   C:/MinGW/bin/ld: z\bli_pthread.o:bli_pthread.c:(.text+0xb1): undefined reference to `pthread_once'
#                   C:/MinGW/bin/ld: z\bli_pthread.o:bli_pthread.c:(.text+0xc1): undefined reference to `pthread_barrier_init'
#                   C:/MinGW/bin/ld: z\bli_pthread.o:bli_pthread.c:(.text+0xd1): undefined reference to `pthread_barrier_destroy'
#                   C:/MinGW/bin/ld: z\bli_pthread.o:bli_pthread.c:(.text+0xe1): undefined reference to `pthread_barrier_wait'
#                   clang: error: linker command failed with exit code 1 (use -v to see invocation)
#                   error: command 'C:\\MinGW\\bin\\clang.exe' failed with exit code 1
#                   [end of output]
#
#               note: This error originates from a subprocess, and is likely not a problem with pip.
#               ERROR: Failed building wheel for blis
#             Failed to build blis
#             ERROR: ERROR: Failed to build installable wheels for some pyproject.toml based projects (blis)
#             [end of output]
#
#         note: This error originates from a subprocess, and is likely not a problem with pip.
#       error: subprocess-exited-with-error
#
#       Ã— pip subprocess to install build dependencies did not run successfully.
#       â”‚ exit code: 1
#       â•°â”€> See above for output.
#
#       note: This error originates from a subprocess, and is likely not a problem with pip.
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: subprocess-exited-with-error
#
# × pip subprocess to install build dependencies did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.

# %%
import spacy
print(f"spaCy version: {spacy.__version__}")

import sys
print(f"Python version: {sys.version}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 import spacy
#       2 print(f"spaCy version: {spacy.__version__}")
#       4 import sys
#
# ModuleNotFoundError: No module named 'spacy'

# %%
import spacy
import en_core_web_sm

nlp = en_core_web_sm.load()
doc = nlp("This is a sentence.")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import spacy
# ----> 2 import en_core_web_sm
#       4 nlp = en_core_web_sm.load()
#       5 doc = nlp("This is a sentence.")
#
# ModuleNotFoundError: No module named 'en_core_web_sm'

# %%
# Load SpaCy's pre-trained English model
nlp = spacy.load('en_core_web_sm')

# Step 1: Create the text classifier component
text_cat = nlp.create_pipe('textcat', config={"exclusive_classes": True, "architecture": "simple_cnn"})
nlp.add_pipe(text_cat, last=True)
